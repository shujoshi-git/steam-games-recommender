# %% [markdown]
# # Steam Games Data Analysis & Recommendation System
#
# Introduction: The purpose of this project is to build a recommendation system for PC games using Steam data. We also visualize this data and answer several buisness questions such as:
#
#     1. Which genres generate the most revenue?
#
#     2. Games of which genres are played the most (by number of hours)?
#
#     3. How well do positive ratings by users coorelate with the revenue generated by a game?
#
#     4. How popular are games for which discounts are offerent as opposed to those for which none are offered?

# %% [markdown]
# # I. Data: Cleaning, Preprocessing & Visualizing
#
# The data we'll use is taken from Kaggle: https://www.kaggle.com/datasets/fronkongames/steam-games-dataset
#
# This dataset is fairly large: 122,6211 rows (games/rows) and 39 features (columns). We choose to work with the csv file instead of json since the data is mostly tabular. There are several problems with the data and we will spend a fair bit of time making the data usable. In particular:
#
#     1. We'll drop certain features that don't give us useful information: like URLs. There are some games with zero users! We'll drop these.
#
#     2. A few features have no values for most rows: we'll have to drop these as well.
#
#     3. Several column names don't correspond with the values in the rows. i.e., there is a mismatch of column name and what values they contain.
#
#     4. There might be duplicate games (this is likely because some game publishers release different versions of a game in different countries.)
#
# Let's begin by loading the data and exploring what it looks like.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Python/Data Science Projects/Data/games.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 122611 entries, 2539430 to 4141790
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   AppID                       122610 non-null  str
#  1   Name                        122611 non-null  str
#  2   Release date                122611 non-null  str
#  3   Estimated owners            122611 non-null  int64
#  4   Peak CCU                    122611 non-null  int64
#  5   Required age                122611 non-null  float64
#  6   Price                       122611 non-null  int64
#  7   DiscountDLC count           122611 non-null  int64
#  8   About the game              114162 non-null  str
#  9   Supported languages         122611 non-null  str
#  10  Full audio languages        122611 non-null  str
#  11  Reviews                     12070 non-null   str
#  12  Header image                122530 non-null  str
# ...

# %%
df.shape
# Out:
# (122611, 39)

# %%
df.head()
# Out:
#                                          AppID          Name Release date  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023        0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016    0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019    0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024    0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025    0 - 20000
#
#          Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 2539430                 0         0          0.00      0                  0
# 496350                  0         0          5.24     65                  0
# 1034400                 0         0          4.99      0                  0
# 3292190                 1         0          8.99      0                  1
# 3631080                 0         0          4.99      0                  0
#
#                                             About the game  \
# ...

# %% [markdown]
# We observe that there are several issues with this dataset. For now we focus on the features.
#
# 1. The names of the first nine attrributes (columns) are incorrectly aligned. In particular, the feature "DiscountDLC count" should be two separate features.
# 2. While the feature AppID can serve as a unique datapoint (row) identifier, we will reindex the rows using positive integers.
# 3. We drop features don't contain useful data or sometimes, any data (NaN) at all. In particular, several features contain only URL that are of no use.
# 4. We will repurpose some features and engineer new ones from old features.
# 5. Features like "Categories" and "Tags" are of utmost important for our recommender system and we will need to preprocess these features, among others.
# 6. Etcetra...
#
# We will address games (rows) at a later time.

# %%
df.columns = ['Name', 'Release date', 'Estimated owners', 'Peak CCU',
       'Required age', 'Price', 'Discount', 'DLC count', 'About the game',
       'Supported languages', 'Full audio languages', 'Reviews',
       'Header image', 'Website', 'Support url', 'Support email', 'Windows',
       'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 'User score',
       'Positive', 'Negative', 'Score rank', 'Achievements', 'Recommendations',
       'Notes', 'Average playtime forever', 'Average playtime two weeks',
       'Median playtime forever', 'Median playtime two weeks', 'Developers',
       'Publishers', 'Categories', 'Genres', 'Tags', 'Screenshots', 'Movies']

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# We begin by dropping features that will serve us no purpose. We list them below and provide brief reasoning for dropping them.
#
# 1. **Required age**: We assume that any user of our recommender system is an adult. Moreover, this feature is highly unreliable: many game developers enter required age as "0" even though the game may contain elements that are inappropriate for younger gamers. Additionally, we don't intend to use this feature in any of our business analysis. To make up for the loss of this, we will drop games that contain undesired elements. See [Jump to Section](#Removing-games-with-undesired-elements)
# 2. **Full audio languages**: A list of audio languages a game supports. Niche or low budget indie games often cannot support audio in foreign languages. As such this feature is not an indicator of quality of a game, only its production budget. We will however use "Supported langauges" by coverting this feature into "Language count" that will give the number of langauges a given game supports. We intend to use this feature as a tie-breaker in our recommender system.
# 3. **Website**: We will delete this feature that contains a lot of NaN fields. Instead we will create a new feature with the same name that will give the Steam webpage of a game in our recommender system.
# 4. **Support URL, Support email**: Links for owners of a game to get service and support. These features are not useful to us.
# 5. **Windows, Mac, Linux**: Boolean features telling us whether a game is supported for the given operating system. We notice below that almost all games are supported on Windows and there are only 32 games for Mac that don't run on Windows. As such, since most games are supported on Windows, we will simply get rid of these features. If our recommender ends up recommending a Linux only game to a Windows user, we trust the user will check the requirements to run the game on their computer.
# 6. **Metacritic score, Metacritic url**: The vast majority of the feature "Metacritic score" is 0; this is a sparse feature. This means there is no data available. We can safely drop this feature. We also have no purpose of the corresponding URL feature.
# 7. **User score, user rank**: Note below that there are only 40 games that have non-zero "User score"; another sparse feature. We will also drop is statistically insignificant feature. This will affect the feature "Score rank" which is supposed to be a relative ranking of games based on "User score". As we see below, 'Score rank' contains no useful data and so we drop it as well.
# 8. **Average playtime two weeks, Median playtime two weeks**: These two features are less reliable than their "forever" counterparts. They measure a game's acitivity for a very short duration of time. As such, the "forever" playtime metrics are better indicators of a game's engagement and we therefore drop these inferior features.
# 9. **Achievements**: Gives the number of achievements a game offers. This number is highly unreliable. Many games offer a large number of achievements to attract gamers but the game itself lacks quality. On the other hand 100 achievements in Racing might be significaly easier (or harder) than 100 achievements in Puzzle or RPG games. As such, we don't see a way to meaningfully use this feature and therefore drop it.
# 10. **Screenshots**: A link to a game's screenshots. Not a useful feature for us.
# 11. **Movies**: Contains no data; all entries are NaN.

# %%
# Notice that many features are strings that are URL. Most of these are not useful to us.

df.iloc[0:5, 14:18]
# Out:
#                                   Support url                Support email  \
# 2539430                                   NaN                          NaN
# 496350                  http://mangagamer.com       support@mangagamer.com
# 1034400  https://www.facebook.com/8FloorGames           support@8floor.net
# 3292190                                   NaN        yujingamesc@gmail.com
# 3631080       https://www.realityexpanded.com  support@realityexpanded.com
#
#          Windows    Mac
# 2539430     True  False
# 496350      True  False
# 1034400     True   True
# 3292190     True  False
# 3631080     True  False

# %%
# Most games run on Windows while the number of games that run on Mac or Linux but not on Windows is negligible. 

print((df['Windows'] == False).sum()) # Number of games that don't run on Windows.
print(df[(df['Linux'] == True) & (df['Windows'] == False)].shape[0]) # Number of Linux games that don't run on Windows. 
print(df[(df['Mac'] == True) & (df['Windows'] == False)].shape[0]) # Number of Mac games that don't run on Windows.
# Out:
# 44
# 14
# 32

# %%
# A score of "0" for "Metacritic score" means that no data is available for that game. Most entries are zero. 

print((df['Metacritic score'] != 0).sum())
# Out:
# 4256

# %%
# "User score" contains effectively no data. As a consequence, "Score rank" is a meaningless feature. 

print((df['User score'] != 0).sum())
print(df['Score rank'].nunique())
# Out:
# 40
# 3

# %%
# The feature "Movies" contains no data.

print(df['Movies'].count())
# Out:
# 0

# %% [markdown]
# ## Dropping features:
# We now drop all columns we wish to at the same time and take a look at what our data now looks like. Note that we are not entirely done with dropping features. We will use certain features like "About the game", "Reviews" and "AppID" and then drop them once their usage is exhausted.

# %%
df = df.drop(columns = ['Required age','Full audio languages', 'Website', 'Support url', 'Support email', 'Windows', 'Mac', 'Linux', 'Metacritic score', 'Metacritic url', 
                   'User score', 'Score rank', 'Average playtime two weeks', 'Median playtime two weeks', 'Achievements', 'Screenshots', 'Movies']);

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 122611 entries, 2539430 to 4141790
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Name                      122610 non-null  str
#  1   Release date              122611 non-null  str
#  2   Estimated owners          122611 non-null  str
#  3   Peak CCU                  122611 non-null  int64
#  4   Price                     122611 non-null  float64
#  5   Discount                  122611 non-null  int64
#  6   DLC count                 122611 non-null  int64
#  7   About the game            114162 non-null  str
#  8   Supported languages       122611 non-null  str
#  9   Reviews                   12070 non-null   str
#  10  Header image              122530 non-null  str
#  11  Positive                  122611 non-null  int64
#  12  Negative                  122611 non-null  int64
#  13  Recommendations           122611 non-null  int64
# ...

# %% [markdown]
# ### Data Preporcessing
#
# We now work on rows.

# %% [markdown]
# Let's start by checking if there are duplicate rows. Duplicate rows will have identical entires for each feature. The pandas function drop_duplicates() will keep one copy while tossing out the other duplicate ones.

# %%
n = df.duplicated().sum() # Number of duplicate rows.
print(f"There are {n} duplicate rows.")

df = df.drop_duplicates() # Our dataframe now contains no duplicate rows.
# Out:
# There are 7 duplicate rows.

# %%
df['Name'].describe()
# Out:
# count                                            122603
# unique                                           121454
# top       Shadow of the Tomb Raider: Definitive Edition
# freq                                                 20
# Name: Name, dtype: object

# %% [markdown]
# **Case Study 1: Dealing with duplicate Names**
#
# There are games with the exact same name. There are a few main reasons for this:
# 1. The game was relased in a different region (and perhaps in a different language) of the world at a different time than its original release.
# 2. A slightly different version of the game was released (director's cut, extended edition, anniversary edition, remaster, etc.) but the name was the game was kept identical.
# 3. Several games could be named "Solitarie" but could be developed by different developers and as such, could be different games in terms of experience.
#
# We must decide how to handle this problem. There are two options:
#
#     A. Keep the duplicates. The recommender will be constructed to choose the best performing one, in case of a tie between two versions of a game.
#
#     B. Keep only the best performing version: We could sort the games by metrics of performance: Peak CCU and/or Revenue (feature to be introduced below) and then we keep only the top version of the game.
#
# Decision: We keep the games with duplicate names. Note that these are not true duplicates: they differ in terms of other features. Moreover, all games have unique AppID and we will use this when recommending games. It is best not to throw out data unless absolutely necessary.

# %% [markdown]
# Next, we find any rows that don't contain "Name" and then drop any such game.

# %%
df[df['Name'].isnull()]
# Out:
#        Name Release date Estimated owners  Peak CCU  Price  Discount  \
# 396420  NaN  Nov 1, 2016            0 - 0         0    0.0         0
#
#         DLC count                                     About the game  \
# 396420          0  Spookeningは3Dの恐怖ゲームで、あなたは毎夜に死んでゴーストとして復活します。 村...
#
#        Supported languages Reviews  ... Negative  Recommendations  Notes  \
# 396420                  []     NaN  ...        0                0    NaN
#
#         Average playtime forever Median playtime forever  Developers  \
# 396420                         0                       0         NaN
#
#         Publishers Categories Genres Tags
# 396420         NaN        NaN    NaN  NaN
#
# [1 rows x 22 columns]

# %%
df.dropna(subset=['Name'], inplace=True) # Drop the row with the null "Name".

# %% [markdown]
# ### Removing games with undesired elements
#
# We now work on the rows and start by removing games that contain undesired elements. We do this performing a word search and then changing our dataframe to leave those games alone that do NOT contain these words.

# %%
# Words we wish to search
words = 'extreme violence|torture|intercourse|prostitution|pornography|pornographic|hentai|masturbation|sexual content'

# Search these words across relevant features
nope_words = (df['About the game'].str.contains(words, case=False, na=False)) | \
       (df['Reviews'].str.contains(words, case=False, na=False)) | \
       (df['Notes'].str.contains(words, case=False, na=False)) | \
       (df['Genres'].str.contains(words, case=False, na=False)) | \
       (df['Categories'].str.contains(words, case=False, na=False)) | \
       (df['Tags'].str.contains(words, case=False, na=False)) 
       
df = df[~nope_words]

# %%
df.shape
# Out:
# (114445, 22)

# %%
df.head()
# Out:
#                                           Name  Release date Estimated owners  \
# 2539430             Black Dragon Mage Playtest   Aug 1, 2023            0 - 0
# 496350   Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016        0 - 20000
# 1034400      Mystery Solitaire The Black Raven   May 6, 2019        0 - 20000
# 3292190            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024        0 - 20000
# 3631080                          Maze Quest VR  Apr 24, 2025        0 - 20000
#
#          Peak CCU  Price  Discount  DLC count  \
# 2539430         0   0.00         0          0
# 496350          0   5.24        65          0
# 1034400         0   4.99         0          0
# 3292190         1   8.99         0          1
# 3631080         0   4.99         0          0
#
#                                             About the game  \
# 2539430                                                NaN
# 496350   Springtime, April: when the cherry trees come ...
# ...

# %%
all_categories = []

for entry in df["Categories"].dropna():
    categories = [g.strip() for g in entry.split(",")]
    all_categories.extend(categories)

unique_categories = sorted(set(all_categories))
print(unique_categories)
# Out:
# ['Adjustable Difficulty', 'Adjustable Text Size', 'Camera Comfort', 'Captions available', 'Chat Speech-to-text', 'Chat Text-to-speech', 'Co-op', 'Color Alternatives', 'Commentary available', 'Cross-Platform Multiplayer', 'Custom Volume Controls', 'Family Sharing', 'Full controller support', 'HDR available', 'In-App Purchases', 'Includes Source SDK', 'Includes level editor', 'Keyboard Only Option', 'LAN Co-op', 'LAN PvP', 'MMO', 'Mods', 'Mods (require HL2)', 'Mouse Only Option', 'Multi-player', 'Narrated Game Menus', 'Online Co-op', 'Online PvP', 'Partial Controller Support', 'Playable without Timed Input', 'PvP', 'Remote Play Together', 'Remote Play on Phone', 'Remote Play on TV', 'Remote Play on Tablet', 'Save Anytime', 'Shared/Split Screen', 'Shared/Split Screen Co-op', 'Shared/Split Screen PvP', 'Single-player', 'Stats', 'Steam Achievements', 'Steam Cloud', 'Steam Leaderboards', 'Steam Timeline', 'Steam Trading Cards', 'Steam Turn Notifications', 'Steam Workshop', 'SteamVR Collect
# ...

# %%
all_tags = []

for entry in df["Tags"].dropna():
    tags = [g.strip() for g in entry.split(",")]
    all_tags.extend(tags)

unique_tags = sorted(set(all_tags))
print(unique_tags)
# Out:
# ['1980s', "1990's", '2.5D', '2D', '2D Fighter', '2D Platformer', '360 Video', '3D', '3D Fighter', '3D Platformer', '3D Vision', '4 Player Local', '4X', '6DOF', '8-bit Music', 'ATV', 'Abstract', 'Action', 'Action RPG', 'Action RTS', 'Action Roguelike', 'Action-Adventure', 'Addictive', 'Adventure', 'Agriculture', 'Aliens', 'Alternate History', 'Ambient', 'America', 'Animation & Modeling', 'Anime', 'Arcade', 'Archery', 'Arena Shooter', 'Artificial Intelligence', 'Assassin', 'Asymmetric VR', 'Asynchronous Multiplayer', 'Atmospheric', 'Audio Production', 'Auto Battler', 'Automation', 'Automobile Sim', 'BMX', 'Base-Building', 'Baseball', 'Based On A Novel', 'Basketball', 'Batman', 'Battle Royale', "Beat 'em up", 'Beautiful', 'Benchmark', 'Bikes', 'Birds', 'Blood', 'Board Game', 'Boomer Shooter', 'Boss Rush', 'Bowling', 'Boxing', 'Building', 'Bullet Hell', 'Bullet Time', 'CRPG', 'Capitalism', 'Card Battler', 'Card Game', 'Cartoon', 'Cartoony', 'Casual', 'Cats', 'Character Action Game', 'Cha
# ...

# %% [markdown]
# Lastly, we add an index to our dataframe.

# %%
# Add a column that indexes the rows using positive integers.

df = df.reset_index(drop=True)
df.index = df.index + 1

# %%
df.head()
# Out:
#                                     Name  Release date Estimated owners  \
# 1             Black Dragon Mage Playtest   Aug 1, 2023            0 - 0
# 2  Supipara - Chapter 1 Spring Has Come!  Jul 29, 2016        0 - 20000
# 3      Mystery Solitaire The Black Raven   May 6, 2019        0 - 20000
# 4            버튜버 파라노이아 - Vtuber Paranoia  Oct 31, 2024        0 - 20000
# 5                          Maze Quest VR  Apr 24, 2025        0 - 20000
#
#    Peak CCU  Price  Discount  DLC count  \
# 1         0   0.00         0          0
# 2         0   5.24        65          0
# 3         0   4.99         0          0
# 4         1   8.99         0          1
# 5         0   4.99         0          0
#
#                                       About the game  \
# 1                                                NaN
# 2  Springtime, April: when the cherry trees come ...
# 3  Immerse yourself in the most beloved, mystical...
# 4  synopsis 'Hello, I'm Hiyoro, a new YouTuber!' ...
# ...

# %% [markdown]
# # Business
#
# ## Revenue Estimation
#
# We would like to get an estimate of revenue generated by each game. To do this, we define Estimated revenue = Estimated owners X Price. In doing so, we are making several assumptions:
#
# 1. Since "Price" is in USD, we are ignoring the fact that games are also bought by people outside the US using currencies different from the USD.
# 2. Many games go on discount a few times a year so the actual revenue generated is typically lower.
# 3. Steam takes a cut from the price a buyer pays for a game so the actual revenue a game developer generates is smaller. Similarly, several other "middle men" take their cut, for example, the game publisher, game promoters, etc.
# 4. There are "fremium" games
# 5. Lastly, the entries in the feature "Price" are proabably recorded at the time this dataset was created and the typical price of a game may fluctuate over time.
#
# Of course, this is far from an ideal estimate, but nonetheless, "Estimated revenue" will give us an indication of how a paid game has performed financially. We keep in mind that "Estimated revenue" will typically be a gross upper bound of the actual revenue generated by the game.

# %%
df['Estimated owners'].unique()
# Out:
# <StringArray>
# [                '0 - 0',             '0 - 20000',       '100000 - 200000',
#       '500000 - 1000000',         '20000 - 50000',       '200000 - 500000',
#         '50000 - 100000',     '2000000 - 5000000',   '10000000 - 20000000',
#      '1000000 - 2000000',   '20000000 - 50000000',    '5000000 - 10000000',
#  '100000000 - 200000000',  '50000000 - 100000000']
# Length: 14, dtype: str

# %% [markdown]
# First note that "Estimated owners" is a string-type range. We will create a new feature "Average owners" by converting a given range to an integer by taking the midpoint of each range. For example, the range 50,000 - 100,000 will be converted to the integer 75,000.

# %%
# Split the 'Estimated owners' column into two temporary columns
owners_split = df['Estimated owners'].str.split('-', expand=True).astype(float)

# Calculate the average of the range
# owners_split[0] is the low end, owners_split[1] is the high end
df['Average owners'] = (owners_split[0] + owners_split[1]) / 2

# Multiply by Price to get Estimated revenue
df['Estimated revenue'] = df['Average owners'] * df['Price']

# %% [markdown]
# Let's reorder the games by "Estimated revenue" in descending to see if we recognize some of the games. This seems like a much better head for this dataset!

# %%
df = df.sort_values(by='Estimated revenue', ascending=False);
df.iloc[0:20, 0]
# Out:
# 41212                            Black Myth: Wukong
# 15712                                      Palworld
# 107237                                   ELDEN RING
# 1341                           Monster Hunter Wilds
# 60943                                 HELLDIVERS™ 2
# 3822                                Path of Exile 2
# 96715                                    Last Epoch
# 242                               Battlefield™ 2042
# 64329                                Cyberpunk 2077
# 5012                                           Rust
# 85338                              EA SPORTS FC™ 25
# 103628                              DARK SOULS™ III
# 54681     Sekiro™: Shadows Die Twice - GOTY Edition
# 4759                                   Satisfactory
# 70403                  Mount & Blade II: Bannerlord
# 19790                                 7 Days to Die
# 13203                         ARK: Survival Evolved
# 50862                                          DayZ
# ...

# %% [markdown]
# ## Visualizing the most successful genres
#
# Let's look at the genres of the top 1% games by estimated revenue. We do this by creating a word bubble to visualize which genres appear most often for this top 1% category. This will give us an idea of which genres perform well financially. We start by looking at the data contained in the "Genres" feature more closely.

# %%
df.shape
# Out:
# (114445, 24)

# %%
df.iloc[0:5, 29:30]
# Out:
# Empty DataFrame
# Columns: []
# Index: [41212, 15712, 107237, 1341, 60943]

# %% [markdown]
# Let's create a new dataframe (called top_1_percent) that contains the top 1% of our main dataframe. Then we'll first look at all the genres of the top 1% of the games.

# %%
top_1_percent = df.head(int(len(df) * 0.01))

all_genres = []

for entry in top_1_percent["Genres"].dropna():
    genres = [g.strip() for g in entry.split(",")]
    all_genres.extend(genres)

unique_genres = sorted(set(all_genres))
print(unique_genres)
# Out:
# ['Action', 'Adventure', 'Animation & Modeling', 'Audio Production', 'Casual', 'Design & Illustration', 'Early Access', 'Education', 'Free To Play', 'Game Development', 'Indie', 'Massively Multiplayer', 'Photo Editing', 'RPG', 'Racing', 'Simulation', 'Software Training', 'Sports', 'Strategy', 'Utilities', 'Video Production', 'Web Publishing']

# %% [markdown]
# Now we move on to create the Word Cloud.

# %%
from collections import Counter
import ast
import matplotlib.patches as mpatches
import numpy as np
from wordcloud import WordCloud

# %%
genre_counts = Counter(all_genres)

# %%
wc = WordCloud(
    width=1200,
    height=800,
    background_color="white",
    colormap="tab10",       # a colormap with distinct colors per genre
    max_words=50            # limit to top 50 genres if there are many
)

wc.generate_from_frequencies(genre_counts)

# %%
plt.figure(figsize=(14, 9))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.title("Top 1% Games by Revenue — Genre Distribution", fontsize=18, pad=20)
plt.tight_layout()
plt.show()

# %% [markdown]
# This is a nice visual resprentation genres most successful by revenue. However, to be more analytically rigorous, let's use a bar chart to represent the game data - since our data ("Genres") is of categorical type, a bar chart is more approproate than a histogram.

# %%
# Count already done from before, just convert to a sorted DataFrame for plotting
genre_df = pd.DataFrame(genre_counts.most_common(), columns=["Genre", "Count"])

# Plot
plt.figure(figsize=(14, 8))
plt.bar(genre_df["Genre"], genre_df["Count"], color="midnightblue", edgecolor="white")

plt.title("Genre Frequency — Top 1% Games by Revenue", fontsize=16, pad=15)
plt.xlabel("Genre", fontsize=12)
plt.ylabel("Number of Games", fontsize=12)
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# However, note that the above distribution is not an accurate description of the success of a genre. The reason is that there are typically far more "Action" games than "Racing" games so it makes sense that the "Action" tag appears more often in the distribution. Therefore, we'll take the number of games with the tag "Action" and

# %% [markdown]
# This is excellent! We keep in mind that genres are not mutualy exclusive. A single game typically has multiple genres. Let's draw some elementary conclusions.
#
# 1. Nearly 750 games out of 1195 games contain the Genre "Action".
# 2. The top 1% of the games don't contain many games with the genres "Sports" or "Racing". This may signal an opportunity (and a need) to make these games more popular.
# 3. About 100 games are "Early Access". These are games that are made available to purchase and play before their development is complete. That's about 8.3% of the top 1% of the games.

# %% [markdown]
# Now let's address those rows that have way too many NaN or null values.

# %%
print(df['Name'].duplicated().sum())
# Out:
# 1054

# %% [markdown]
# These duplicates mainly fall under one these cases:
#
# 1. Different versions of the base game. Some examples: Game of the Year Edition, Extended Edition, Developer's cut, etc.
# 2. A foreign language verison of the game that was released disjoint from the initial version.
# 3. Actual duplicates.
#
#
# We now prescribe criteria which will determine which of these duplicates must be removed. We must also remove the column "Achievements".

# %% [markdown]
# # Science: Recommendation System
#
# In this final chapter of this project, we will construct a recommendation system. A user will input a video game's name and the system will output a few games that the user is likely to enjoy. Our recommendation system is content-based. This means that it uses the features of an input to recommend new content.
#
# ## The recommendation system has three very important features:
# 1. In addition to suggesting five games that the user is likely to enjoy, the system also recommends three games that are "less" similar than the first 5. These latter three games raise the odds of discovering a "hidden gem".
# 2. At least one recommended game is free to play!
# 3. In the event the user inputs a game that does not exist in our dataset, the system will prompt the user to try again by suggesting a few popular games from the database that the user is likely to know. In addition, it will display an inforgraphic that shows certain statistics of genres and categories. This helps address one aspect of cold start problem.
#
# ## Architecture of the recommendation system:
# We use $k$-means clustering to create clusters where games within one cluster are similar in genre and "feel". Then we use $k$-nearest neighbors to select games within a given cluster.
